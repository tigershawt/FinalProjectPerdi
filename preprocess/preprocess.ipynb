# %%
import pandas as pd

# %%
DimAccounts = pd.read_csv("source_data\dbo.DimAccount.csv")

DimCurrency = pd.read_csv("source_data\dbo.DimCurrency.csv")

DimCustomer = pd.read_csv("source_data\dbo.DimCustomer.csv")

DimDate = pd.read_csv("source_data\dbo.DimDate.csv")

DimDepartmentGroup = pd.read_csv("source_data\dbo.DimDepartmentGroup.csv")

DimGeography = pd.read_csv("source_data\dbo.DimGeography.csv")

DimOrganization = pd.read_csv("source_data\dbo.DimOrganization.csv")

DimProduct = pd.read_csv("source_data\dbo.DimProduct.csv")

DimProductCategory = pd.read_csv("source_data\dbo.DimProductCategory.csv")

DimProductSubcategory = pd.read_csv("source_data\dbo.DimProductSubcategory.csv")

DimPromotion = pd.read_csv("source_data\dbo.DimPromotion.csv")

DimReseller = pd.read_csv("source_data\dbo.DimReseller.csv")

DimSalesReason = pd.read_csv("source_data\dbo.DimSalesReason.csv")

DimSalesTerritory = pd.read_csv("source_data\dbo.DimSalesTerritory.csv")

DimScenario = pd.read_csv("source_data\dbo.DimScenario.csv")

FactAdditionalInternationalProductDescription = pd.read_csv("source_data\dbo.FactAdditionalInternationalProductDescription.csv")

FactCallCenter = pd.read_csv("source_data\dbo.FactCallCenter.csv")

FactCurrencyRate = pd.read_csv("source_data\dbo.FactCurrencyRate.csv")

FactInternetSales = pd.read_csv("source_data\dbo.FactInternetSales.csv")

FactInternetSalesReason = pd.read_csv("source_data\dbo.FactInternetSalesReason.csv")

FactProductInventory = pd.read_csv("source_data\dbo.FactProductInventory.csv")

FactResellerSales = pd.read_csv("source_data\dbo.FactResellerSales.csv")

FactSalesQuota = pd.read_csv("source_data\dbo.FactSalesQuota.csv")

FactSurveyResponse = pd.read_csv("source_data\dbo.FactSurveyResponse.csv")

NewFactCurrencyRate = pd.read_csv("source_data\dbo.NewFactCurrencyRate.csv")

ProspectiveBuyer = pd.read_csv("source_data\dbo.ProspectiveBuyer.csv")

vAssocSeqLineItems = pd.read_csv("source_data\dbo.vAssocSeqLineItems.csv")

vAssocSeqOrders = pd.read_csv("source_data\dbo.vAssocSeqOrders.csv")

vDMPrep = pd.read_csv("source_data\dbo.vDMPrep.csv")

vTargetMail = pd.read_csv("source_data\dbo.vTargetMail.csv")

vTimeSeries = pd.read_csv("source_data\dbo.vTimeSeries.csv")

# %%
DimAccounts.head()
# Out:
#    AccountKey  ParentAccountKey  AccountCodeAlternateKey  \
# 0           1               NaN                        1
# 1           2               1.0                       10
# 2           3               2.0                      110
# 3           4               3.0                     1110
# 4           5               3.0                     1120
#
#    ParentAccountCodeAlternateKey AccountDescription AccountType Operator  \
# 0                            NaN      Balance Sheet         NaN        ~
# 1                            1.0             Assets      Assets        +
# 2                           10.0     Current Assets      Assets        +
# 3                          110.0               Cash      Assets        +
# 4                          110.0        Receivables      Assets        +
#
#   CustomMembers ValueType  CustomMemberOptions
# 0           NaN  Currency                  NaN
# 1           NaN  Currency                  NaN
# ...

# %%
print(DimAccounts.dtypes)
# Out:
# AccountKey                         int64
# ParentAccountKey                 float64
# AccountCodeAlternateKey            int64
# ParentAccountCodeAlternateKey    float64
# AccountDescription                object
# AccountType                       object
# Operator                          object
# CustomMembers                     object
# ValueType                         object
# CustomMemberOptions              float64
# dtype: object

# %%
DimCurrency.head()
# Out:
#    CurrencyKey CurrencyAlternateKey    CurrencyName
# 0            1                  AFA         Afghani
# 1            2                  DZD  Algerian Dinar
# 2            3                  ARS  Argentine Peso
# 3            4                  AMD   Armenian Dram
# 4            5                  AWG  Aruban Guilder

# %%
print(DimCurrency.dtypes)
# Out:
# CurrencyKey              int64
# CurrencyAlternateKey    object
# CurrencyName            object
# dtype: object

# %%
DimCustomer.head()
# Out:
#    CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName MiddleName  \
# 0        11000            26           AW00011000   NaN        Jon          V
# 1        11001            37           AW00011001   NaN     Eugene          L
# 2        11002            31           AW00011002   NaN      Ruben        NaN
# 3        11003            11           AW00011003   NaN    Christy        NaN
# 4        11004            19           AW00011004   NaN  Elizabeth        NaN
#
#   LastName  NameStyle   BirthDate MaritalStatus  ... EnglishOccupation  \
# 0     Yang      False  06.10.1971             M  ...      Professional
# 1    Huang      False  10.05.1976             S  ...      Professional
# 2   Torres      False  09.02.1971             M  ...      Professional
# 3      Zhu      False  14.08.1973             S  ...      Professional
# 4  Johnson      False  05.08.1979             S  ...      Professional
#
# ...

# %%
print(DimCustomer.dtypes)
# Out:
# CustomerKey              int64
# GeographyKey             int64
# CustomerAlternateKey    object
# Title                   object
# FirstName               object
# MiddleName              object
# LastName                object
# NameStyle                 bool
# BirthDate               object
# MaritalStatus           object
# Suffix                  object
# Gender                  object
# EmailAddress            object
# YearlyIncome            object
# TotalChildren            int64
# NumberChildrenAtHome     int64
# EnglishEducation        object
# SpanishEducation        object
# FrenchEducation         object
# EnglishOccupation       object
# SpanishOccupation       object
# FrenchOccupation        object
# HouseOwnerFlag           int64
# NumberCarsOwned          int64
# AddressLine1            object
# AddressLine2            object
# Phone                   object
# DateFirstPurchase       object
# CommuteDistance         object
# dtype: object

# %%
DimDate.head()
# Out:
#     DateKey FullDateAlternateKey  DayNumberOfWeek EnglishDayNameOfWeek  \
# 0  20050101           01.01.2005                7             Saturday
# 1  20050102           02.01.2005                1               Sunday
# 2  20050103           03.01.2005                2               Monday
# 3  20050104           04.01.2005                3              Tuesday
# 4  20050105           05.01.2005                4            Wednesday
#
#   SpanishDayNameOfWeek FrenchDayNameOfWeek  DayNumberOfMonth  DayNumberOfYear  \
# 0               Sábado              Samedi                 1                1
# 1              Domingo            Dimanche                 2                2
# 2                Lunes               Lundi                 3                3
# 3               Martes               Mardi                 4                4
# 4            Miércoles            Mercredi                 5                5
#
# ...

# %%
print(DimDate.dtypes)
# Out:
# DateKey                  int64
# FullDateAlternateKey    object
# DayNumberOfWeek          int64
# EnglishDayNameOfWeek    object
# SpanishDayNameOfWeek    object
# FrenchDayNameOfWeek     object
# DayNumberOfMonth         int64
# DayNumberOfYear          int64
# WeekNumberOfYear         int64
# EnglishMonthName        object
# SpanishMonthName        object
# FrenchMonthName         object
# MonthNumberOfYear        int64
# CalendarQuarter          int64
# CalendarYear             int64
# CalendarSemester         int64
# FiscalQuarter            int64
# FiscalYear               int64
# FiscalSemester           int64
# dtype: object

# %%
DimDepartmentGroup.head()
# Out:
#    DepartmentGroupKey  ParentDepartmentGroupKey  \
# 0                   1                       NaN
# 1                   2                       1.0
# 2                   3                       1.0
# 3                   4                       1.0
# 4                   5                       1.0
#
#                     DepartmentGroupName
# 0                             Corporate
# 1  Executive General and Administration
# 2                  Inventory Management
# 3                         Manufacturing
# 4                     Quality Assurance

# %%
print(DimDepartmentGroup.dtypes)
# Out:
# DepartmentGroupKey            int64
# ParentDepartmentGroupKey    float64
# DepartmentGroupName          object
# dtype: object

# %%
DimGeography.head()
# Out:
#    GeographyKey           City StateProvinceCode StateProvinceName  \
# 0             1     Alexandria               NSW   New South Wales
# 1             2  Coffs Harbour               NSW   New South Wales
# 2             3   Darlinghurst               NSW   New South Wales
# 3             4       Goulburn               NSW   New South Wales
# 4             5      Lane Cove               NSW   New South Wales
#
#   CountryRegionCode EnglishCountryRegionName SpanishCountryRegionName  \
# 0                AU                Australia                Australia
# 1                AU                Australia                Australia
# 2                AU                Australia                Australia
# 3                AU                Australia                Australia
# 4                AU                Australia                Australia
#
#   FrenchCountryRegionName PostalCode  SalesTerritoryKey IpAddressLocator
# ...

# %%
print(DimGeography.dtypes)
# Out:
# GeographyKey                 int64
# City                        object
# StateProvinceCode           object
# StateProvinceName           object
# CountryRegionCode           object
# EnglishCountryRegionName    object
# SpanishCountryRegionName    object
# FrenchCountryRegionName     object
# PostalCode                  object
# SalesTerritoryKey            int64
# IpAddressLocator            object
# dtype: object

# %%
DimOrganization.head()
# Out:
#    OrganizationKey  ParentOrganizationKey  PercentageOfOwnership  \
# 0                1                    NaN                    1.0
# 1                2                    1.0                    1.0
# 2                3                   14.0                    1.0
# 3                4                   14.0                    1.0
# 4                5                   14.0                    1.0
#
#            OrganizationName  CurrencyKey
# 0      AdventureWorks Cycle          100
# 1  North America Operations          100
# 2        Northeast Division          100
# 3        Northwest Division          100
# 4          Central Division          100

# %%
print(DimOrganization.dtypes)
# Out:
# OrganizationKey            int64
# ParentOrganizationKey    float64
# PercentageOfOwnership    float64
# OrganizationName          object
# CurrencyKey                int64
# dtype: object

# %%
DimProduct.head()
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
# 1           2             BA-8327                    NaN
# 2           3             BE-2349                    NaN
# 3           4             BE-2908                    NaN
# 4           5             BL-2036                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                   NaN                 NaN        Adjustable Race
# 1                   NaN                 NaN           Bearing Ball
# 2                   NaN                 NaN        BB Ball Bearing
# 3                   NaN                 NaN  Headset Ball Bearings
# 4                   NaN                 NaN                  Blade
#
#   SpanishProductName FrenchProductName StandardCost  FinishedGoodsFlag  ...  \
# 0                NaN               NaN          NaN              False  ...
# ...

# %%
print(DimProduct.dtypes)
# Out:
# ProductKey                 int64
# ProductAlternateKey       object
# ProductSubcategoryKey    float64
# WeightUnitMeasureCode     object
# SizeUnitMeasureCode       object
# EnglishProductName        object
# SpanishProductName        object
# FrenchProductName         object
# StandardCost              object
# FinishedGoodsFlag           bool
# Color                     object
# SafetyStockLevel           int64
# ReorderPoint               int64
# ListPrice                 object
# Size                      object
# SizeRange                 object
# Weight                    object
# DaysToManufacture          int64
# ProductLine               object
# DealerPrice               object
# Class                     object
# Style                     object
# ModelName                 object
# LargePhoto                object
# EnglishDescription        object
# FrenchDescription         object
# ChineseDescription        object
# ArabicDescription         object
# ...

# %%
DimProductSubcategory.head()
# Out:
#    ProductSubcategoryKey  ProductSubcategoryAlternateKey  \
# 0                      1                               1
# 1                      2                               2
# 2                      3                               3
# 3                      4                               4
# 4                      5                               5
#
#   EnglishProductSubcategoryName SpanishProductSubcategoryName  \
# 0                Mountain Bikes          Bicicleta de montaña
# 1                    Road Bikes        Bicicleta de carretera
# 2                 Touring Bikes            Bicicleta de paseo
# 3                    Handlebars                         Barra
# 4               Bottom Brackets               Eje de pedalier
#
#   FrenchProductSubcategoryName  ProductCategoryKey
# 0                          VTT                   1
# 1                Vélo de route                   1
# 2            Vélo de randonnée                   1
# ...

# %%
print(DimProductSubcategory.dtypes)
# Out:
# ProductSubcategoryKey              int64
# ProductSubcategoryAlternateKey     int64
# EnglishProductSubcategoryName     object
# SpanishProductSubcategoryName     object
# FrenchProductSubcategoryName      object
# ProductCategoryKey                 int64
# dtype: object

# %%
DimPromotion.head()
# Out:
#    PromotionKey  PromotionAlternateKey      EnglishPromotionName  \
# 0             1                      1               No Discount
# 1             2                      2  Volume Discount 11 to 14
# 2             3                      3  Volume Discount 15 to 24
# 3             4                      4  Volume Discount 25 to 40
# 4             5                      5  Volume Discount 41 to 60
#
#                     SpanishPromotionName               FrenchPromotionName  \
# 0                          Sin descuento                     Aucune remise
# 1  Descuento por volumen (entre 11 y 14)  Remise sur quantité (de 11 à 14)
# 2  Descuento por volumen (entre 15 y 24)  Remise sur quantité (de 15 à 24)
# 3  Descuento por volumen (entre 25 y 40)  Remise sur quantité (de 25 à 40)
# 4  Descuento por volumen (entre 41 y 60)  Remise sur quantité (de 41 à 60)
#
#   DiscountPct EnglishPromotionType   SpanishPromotionType  \
# 0         0,0          No Discount          Sin descuento
# ...

# %%
print(DimPromotion.dtypes)
# Out:
# PromotionKey                  int64
# PromotionAlternateKey         int64
# EnglishPromotionName         object
# SpanishPromotionName         object
# FrenchPromotionName          object
# DiscountPct                  object
# EnglishPromotionType         object
# SpanishPromotionType         object
# FrenchPromotionType          object
# EnglishPromotionCategory     object
# SpanishPromotionCategory     object
# FrenchPromotionCategory      object
# StartDate                    object
# EndDate                      object
# MinQty                        int64
# MaxQty                      float64
# dtype: object

# %%
DimReseller.head()
# Out:
#    ResellerKey  GeographyKey ResellerAlternateKey         Phone  \
# 0            1           637           AW00000001  245-555-0173
# 1            2           635           AW00000002  170-555-0127
# 2            3           584           AW00000003  279-555-0130
# 3            4           572           AW00000004  710-555-0173
# 4            5           322           AW00000005  828-555-0186
#
#            BusinessType                ResellerName  NumberEmployees  \
# 0  Value Added Reseller                A Bike Store                2
# 1   Specialty Bike Shop          Progressive Sports               10
# 2             Warehouse    Advanced Bike Components               40
# 3  Value Added Reseller       Modular Cycle Systems                5
# 4   Specialty Bike Shop  Metropolitan Sports Supply               13
#
#   OrderFrequency  OrderMonth  FirstOrderYear  LastOrderYear ProductLine  \
# 0              S         5.0          2011.0         2011.0        Road
# ...

# %%
print(DimReseller.dtypes)
# Out:
# ResellerKey               int64
# GeographyKey              int64
# ResellerAlternateKey     object
# Phone                    object
# BusinessType             object
# ResellerName             object
# NumberEmployees           int64
# OrderFrequency           object
# OrderMonth              float64
# FirstOrderYear          float64
# LastOrderYear           float64
# ProductLine              object
# AddressLine1             object
# AddressLine2             object
# AnnualSales              object
# BankName                 object
# MinPaymentType          float64
# MinPaymentAmount         object
# AnnualRevenue            object
# YearOpened                int64
# dtype: object

# %%
DimSalesReason.head()
# Out:
#    SalesReasonKey  SalesReasonAlternateKey            SalesReasonName  \
# 0               1                        1                      Price
# 1               2                        2               On Promotion
# 2               3                        3     Magazine Advertisement
# 3               4                        4  Television  Advertisement
# 4               5                        5               Manufacturer
#
#   SalesReasonReasonType
# 0                 Other
# 1             Promotion
# 2             Marketing
# 3             Marketing
# 4                 Other

# %%
print(DimSalesReason.dtypes)
# Out:
# SalesReasonKey              int64
# SalesReasonAlternateKey     int64
# SalesReasonName            object
# SalesReasonReasonType      object
# dtype: object

# %%
DimSalesTerritory.head()
# Out:
#    SalesTerritoryKey  SalesTerritoryAlternateKey SalesTerritoryRegion  \
# 0                  1                           1            Northwest
# 1                  2                           2            Northeast
# 2                  3                           3              Central
# 3                  4                           4            Southwest
# 4                  5                           5            Southeast
#
#   SalesTerritoryCountry SalesTerritoryGroup  \
# 0         United States       North America
# 1         United States       North America
# 2         United States       North America
# 3         United States       North America
# 4         United States       North America
#
#                                  SalesTerritoryImage
# 0  0xFFD8FFE000104A46494600010101004800480000FFDB...
# 1  0xFFD8FFE000104A46494600010101004800480000FFDB...
# 2  0xFFD8FFE000104A46494600010101004800480000FFDB...
# 3  0xFFD8FFE000104A46494600010101004800480000FFDB...
# ...

# %%
print(DimSalesTerritory.dtypes)
# Out:
# SalesTerritoryKey              int64
# SalesTerritoryAlternateKey     int64
# SalesTerritoryRegion          object
# SalesTerritoryCountry         object
# SalesTerritoryGroup           object
# SalesTerritoryImage           object
# dtype: object

# %%
DimScenario.head()
# Out:
#    ScenarioKey ScenarioName
# 0            1       Actual
# 1            2       Budget
# 2            3     Forecast

# %%
print(DimScenario.dtypes)
# Out:
# ScenarioKey      int64
# ScenarioName    object
# dtype: object

# %%
FactAdditionalInternationalProductDescription.head()
# Out:
#    ProductKey         CultureName  \
# 0         210           Afrikaans
# 1         210            Albanian
# 2         210              Basque
# 3         210  Bosnian (Cyrillic)
# 4         210     Bosnian (Latin)
#
#                                   ProductDescription
# 0  Ons ligste en beste-gehalte aluminiumraam gema...
# 1  "Trupi ynë prej alumini më të lehtë dhe me cil...
# 2  "Gure kalitate oneneko aluminiozko koadro arin...
# 3  Наш најлакши и висококвалитетни рам израђен од...
# 4  Naš najlakši i visokokvalitetni ram izrađen od...

# %%
print(FactAdditionalInternationalProductDescription.dtypes)
# Out:
# ProductKey             int64
# CultureName           object
# ProductDescription    object
# dtype: object

# %%
FactCallCenter.head()
# Out:
#    FactCallCenterID   DateKey WageType     Shift  LevelOneOperators  \
# 0                 1  20140501  weekday        AM                  2
# 1                 2  20140501  weekday       PM1                  2
# 2                 3  20140501  weekday       PM2                  3
# 3                 4  20140501  weekday  midnight                  1
# 4                 5  20140502  weekday        AM                  2
#
#    LevelTwoOperators  TotalOperators  Calls  AutomaticResponses  Orders  \
# 0                  7               9    405                 283     341
# 1                 10              12    389                 256     251
# 2                 11              14    358                 268     255
# 3                  4               5    219                 140     162
# 4                  8              10    264                 170     189
#
#    IssuesRaised  AverageTimePerIssue ServiceGrade                Date
# ...

# %%
print(FactCallCenter.dtypes)
# Out:
# FactCallCenterID        int64
# DateKey                 int64
# WageType               object
# Shift                  object
# LevelOneOperators       int64
# LevelTwoOperators       int64
# TotalOperators          int64
# Calls                   int64
# AutomaticResponses      int64
# Orders                  int64
# IssuesRaised            int64
# AverageTimePerIssue     int64
# ServiceGrade           object
# Date                   object
# dtype: object

# %%
FactCurrencyRate.head()
# Out:
#    CurrencyKey   DateKey AverageRate EndOfDayRate                Date
# 0            3  20101229         1,0          1,0  29.12.2010 0:00:00
# 1            3  20101230         1,0        1,001  30.12.2010 0:00:00
# 2            3  20101231         1,0          1,0  31.12.2010 0:00:00
# 3            3  20110101         1,0          1,0  01.01.2011 0:00:00
# 4            3  20110102         1,0          1,0  02.01.2011 0:00:00

# %%
print(FactCurrencyRate.dtypes)
# Out:
# CurrencyKey      int64
# DateKey          int64
# AverageRate     object
# EndOfDayRate    object
# Date            object
# dtype: object

# %%
FactInternetSales.head()
# Out:
#    ProductKey  OrderDateKey  DueDateKey  ShipDateKey  CustomerKey  \
# 0         310      20101229    20110110     20110105        21768
# 1         346      20101229    20110110     20110105        28389
# 2         346      20101229    20110110     20110105        25863
# 3         336      20101229    20110110     20110105        14501
# 4         346      20101229    20110110     20110105        11003
#
#    PromotionKey  CurrencyKey  SalesTerritoryKey SalesOrderNumber  \
# 0             1           19                  6          SO43697
# 1             1           39                  7          SO43698
# 2             1          100                  1          SO43699
# 3             1          100                  4          SO43700
# 4             1            6                  9          SO43701
#
#    SalesOrderLineNumber  ...  ProductStandardCost  TotalProductCost  \
# 0                     1  ...           2 171,29 ₽        2 171,29 ₽
# ...

# %%
print(FactInternetSales.dtypes)
# Out:
# ProductKey                 int64
# OrderDateKey               int64
# DueDateKey                 int64
# ShipDateKey                int64
# CustomerKey                int64
# PromotionKey               int64
# CurrencyKey                int64
# SalesTerritoryKey          int64
# SalesOrderNumber          object
# SalesOrderLineNumber       int64
# RevisionNumber             int64
# OrderQuantity              int64
# UnitPrice                 object
# ExtendedAmount            object
# UnitPriceDiscountPct      object
# DiscountAmount            object
# ProductStandardCost       object
# TotalProductCost          object
# SalesAmount               object
# TaxAmt                    object
# Freight                   object
# CarrierTrackingNumber    float64
# CustomerPONumber         float64
# OrderDate                 object
# DueDate                   object
# ShipDate                  object
# dtype: object

# %%
FactInternetSalesReason.head()
# Out:
#   SalesOrderNumber  SalesOrderLineNumber  SalesReasonKey
# 0          SO43697                     1               5
# 1          SO43697                     1               9
# 2          SO43702                     1               5
# 3          SO43702                     1               9
# 4          SO43703                     1               5

# %%
print(FactInternetSalesReason.dtypes)
# Out:
# SalesOrderNumber        object
# SalesOrderLineNumber     int64
# SalesReasonKey           int64
# dtype: object

# %%
FactProductInventory.head()
# Out:
#    ProductKey   DateKey MovementDate UnitCost  UnitsIn  UnitsOut  UnitsBalance
# 0           1  20101228   28.12.2010   0,32 ₽        0         0           875
# 1           1  20101229   29.12.2010   0,32 ₽        0         0           875
# 2           1  20101230   30.12.2010   0,32 ₽        0         0           875
# 3           1  20101231   31.12.2010   0,32 ₽        0         0           875
# 4           1  20110101   01.01.2011   0,32 ₽        0         0           875

# %%
print(FactProductInventory.dtypes)
# Out:
# ProductKey       int64
# DateKey          int64
# MovementDate    object
# UnitCost        object
# UnitsIn          int64
# UnitsOut         int64
# UnitsBalance     int64
# dtype: object

# %%
FactResellerSales.head()
# Out:
#    ProductKey  OrderDateKey  DueDateKey  ShipDateKey  ResellerKey  \
# 0         349      20101229    20110110     20110105          676
# 1         350      20101229    20110110     20110105          676
# 2         351      20101229    20110110     20110105          676
# 3         344      20101229    20110110     20110105          676
# 4         345      20101229    20110110     20110105          676
#
#    EmployeeKey  PromotionKey  CurrencyKey  SalesTerritoryKey SalesOrderNumber  \
# 0          285             1          100                  5          SO43659
# 1          285             1          100                  5          SO43659
# 2          285             1          100                  5          SO43659
# 3          285             1          100                  5          SO43659
# 4          285             1          100                  5          SO43659
#
#    ...  ProductStandardCost  TotalProductCost  SalesAmount    TaxAmt  \
# ...

# %%
print(FactResellerSales.dtypes)
# Out:
# ProductKey                int64
# OrderDateKey              int64
# DueDateKey                int64
# ShipDateKey               int64
# ResellerKey               int64
# EmployeeKey               int64
# PromotionKey              int64
# CurrencyKey               int64
# SalesTerritoryKey         int64
# SalesOrderNumber         object
# SalesOrderLineNumber      int64
# RevisionNumber            int64
# OrderQuantity             int64
# UnitPrice                object
# ExtendedAmount           object
# UnitPriceDiscountPct     object
# DiscountAmount           object
# ProductStandardCost      object
# TotalProductCost         object
# SalesAmount              object
# TaxAmt                   object
# Freight                  object
# CarrierTrackingNumber    object
# CustomerPONumber         object
# OrderDate                object
# DueDate                  object
# ShipDate                 object
# dtype: object

# %%
FactSalesQuota.head()
# Out:
#    SalesQuotaKey  EmployeeKey   DateKey  CalendarYear  CalendarQuarter  \
# 0              1          272  20101229          2010                4
# 1              2          281  20101229          2010                4
# 2              3          282  20101229          2010                4
# 3              4          283  20101229          2010                4
# 4              5          284  20101229          2010                4
#
#   SalesAmountQuota                Date
# 0      28 000,00 ₽  29.12.2010 0:00:00
# 1     367 000,00 ₽  29.12.2010 0:00:00
# 2     637 000,00 ₽  29.12.2010 0:00:00
# 3     565 000,00 ₽  29.12.2010 0:00:00
# 4     244 000,00 ₽  29.12.2010 0:00:00

# %%
print(FactSalesQuota.dtypes)
# Out:
# SalesQuotaKey        int64
# EmployeeKey          int64
# DateKey              int64
# CalendarYear         int64
# CalendarQuarter      int64
# SalesAmountQuota    object
# Date                object
# dtype: object

# %%
FactSurveyResponse.head()
# Out:
#    SurveyResponseKey   DateKey  CustomerKey  ProductCategoryKey  \
# 0                  1  20120309        11001                   3
# 1                  2  20120309        11001                   4
# 2                  3  20120309        11001                   4
# 3                  4  20120424        11017                   3
# 4                  5  20120424        11017                   4
#
#   EnglishProductCategoryName  ProductSubcategoryKey  \
# 0                   Clothing                     24
# 1                Accessories                     30
# 2                Accessories                     32
# 3                   Clothing                     22
# 4                Accessories                     28
#
#   EnglishProductSubcategoryName                Date
# 0                        Tights  09.03.2012 0:00:00
# 1                       Fenders  09.03.2012 0:00:00
# 2               Hydration Packs  09.03.2012 0:00:00
# 3                        Shorts  24.04.2012 0:00:00
# ...

# %%
print(FactSurveyResponse.dtypes)
# Out:
# SurveyResponseKey                 int64
# DateKey                           int64
# CustomerKey                       int64
# ProductCategoryKey                int64
# EnglishProductCategoryName       object
# ProductSubcategoryKey             int64
# EnglishProductSubcategoryName    object
# Date                             object
# dtype: object

# %%
NewFactCurrencyRate.head()
# Out:
#   AverageRate CurrencyID CurrencyDate EndOfDayRate  CurrencyKey  DateKey
# 0         1,0        ARS   03.03.2011          1,0            3      NaN
# 1         1,0        ARS   04.03.2011        1,001            3      NaN
# 2         1,0        ARS   05.03.2011          1,0            3      NaN
# 3         1,0        ARS   06.03.2011          1,0            3      NaN
# 4       1,001        ARS   07.03.2011          1,0            3      NaN

# %%
print(NewFactCurrencyRate.dtypes)
# Out:
# AverageRate      object
# CurrencyID       object
# CurrencyDate     object
# EndOfDayRate     object
# CurrencyKey       int64
# DateKey         float64
# dtype: object

# %%
ProspectiveBuyer.head()
# Out:
#    ProspectiveBuyerKey  ProspectAlternateKey FirstName MiddleName   LastName  \
# 0                    1           21596444800      Adam        NaN  Alexander
# 1                    2                  3003  Adrienne        NaN     Alonso
# 2                    3                  1077   Alfredo          B    Alvarez
# 3                    4                  4779    Arthur          A       Arun
# 4                    5           38032399400    Andrea          M     Bailey
#
#             BirthDate MaritalStatus Gender                      EmailAddress  \
# 0  30.12.1945 0:00:00             M      M  aalexander@lucernepublishing.com
# 1  06.03.1950 0:00:00             M      F        aalonso@alpineskihouse.com
# 2  30.03.1964 0:00:00             S      M        aalvarez@fineartschool.net
# 3  22.03.1985 0:00:00             S      M         aarun@adventure-works.com
# 4  26.04.1965 0:00:00             M      F     abailey@lucernepublishing.com
#
# ...

# %%
print(ProspectiveBuyer.dtypes)
# Out:
# ProspectiveBuyerKey      int64
# ProspectAlternateKey     int64
# FirstName               object
# MiddleName              object
# LastName                object
# BirthDate               object
# MaritalStatus           object
# Gender                  object
# EmailAddress            object
# YearlyIncome            object
# TotalChildren            int64
# NumberChildrenAtHome     int64
# Education               object
# Occupation              object
# HouseOwnerFlag           int64
# NumberCarsOwned          int64
# AddressLine1            object
# AddressLine2            object
# City                    object
# StateProvinceCode       object
# PostalCode               int64
# Phone                   object
# Salutation              object
# Unknown                  int64
# dtype: object

# %%
vAssocSeqLineItems.head()
# Out:
#   OrderNumber  LineNumber             Model
# 0     SO72773           1          Road-750
# 1     SO72773           2      Water Bottle
# 2     SO72773           3  Road Bottle Cage
# 3     SO72773           4         Sport-100
# 4     SO68413           1    Road Tire Tube

# %%
print(vAssocSeqLineItems.dtypes)
# Out:
# OrderNumber    object
# LineNumber      int64
# Model          object
# dtype: object

# %%
vAssocSeqOrders.head()
# Out:
#   OrderNumber  CustomerKey         Region IncomeGroup
# 0     SO61313        11427         Europe        High
# 1     SO61314        11211  North America    Moderate
# 2     SO61315        15146        Pacific        High
# 3     SO61316        21187        Pacific    Moderate
# 4     SO61317        17355        Pacific         Low

# %%
print(vAssocSeqOrders.dtypes)
# Out:
# OrderNumber    object
# CustomerKey     int64
# Region         object
# IncomeGroup    object
# dtype: object

# %%
vDMPrep.head()
# Out:
#   EnglishProductCategoryName         Model  CustomerKey         Region  Age  \
# 0                      Bikes      Road-150        21768  North America   72
# 1                      Bikes  Mountain-100        28389         Europe   53
# 2                      Bikes  Mountain-100        25863  North America   71
# 3                      Bikes      Road-650        14501  North America   80
# 4                      Bikes  Mountain-100        11003        Pacific   50
#
#   IncomeGroup  CalendarYear  FiscalYear  Month OrderNumber  LineNumber  \
# 0        High          2010        2011     12     SO43697           1
# 1         Low          2010        2011     12     SO43698           1
# 2    Moderate          2010        2011     12     SO43699           1
# 3        High          2010        2011     12     SO43700           1
# 4        High          2010        2011     12     SO43701           1
#
#    Quantity      Amount
# 0         1  3 578,27 ₽
# 1         1  3 399,99 ₽
# ...

# %%
print(vDMPrep.dtypes)
# Out:
# EnglishProductCategoryName    object
# Model                         object
# CustomerKey                    int64
# Region                        object
# Age                            int64
# IncomeGroup                   object
# CalendarYear                   int64
# FiscalYear                     int64
# Month                          int64
# OrderNumber                   object
# LineNumber                     int64
# Quantity                       int64
# Amount                        object
# dtype: object

# %%
vTargetMail.head()
# Out:
#    CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName MiddleName  \
# 0        11000            26           AW00011000   NaN        Jon          V
# 1        11001            37           AW00011001   NaN     Eugene          L
# 2        11002            31           AW00011002   NaN      Ruben        NaN
# 3        11003            11           AW00011003   NaN    Christy        NaN
# 4        11004            19           AW00011004   NaN  Elizabeth        NaN
#
#   LastName  NameStyle   BirthDate MaritalStatus  ... HouseOwnerFlag  \
# 0     Yang      False  06.10.1971             M  ...              1
# 1    Huang      False  10.05.1976             S  ...              0
# 2   Torres      False  09.02.1971             M  ...              1
# 3      Zhu      False  14.08.1973             S  ...              0
# 4  Johnson      False  05.08.1979             S  ...              1
#
#   NumberCarsOwned         AddressLine1 AddressLine2                Phone  \
# ...

# %%
print(vTargetMail.dtypes)
# Out:
# CustomerKey              int64
# GeographyKey             int64
# CustomerAlternateKey    object
# Title                   object
# FirstName               object
# MiddleName              object
# LastName                object
# NameStyle                 bool
# BirthDate               object
# MaritalStatus           object
# Suffix                  object
# Gender                  object
# EmailAddress            object
# YearlyIncome            object
# TotalChildren            int64
# NumberChildrenAtHome     int64
# EnglishEducation        object
# SpanishEducation        object
# FrenchEducation         object
# EnglishOccupation       object
# SpanishOccupation       object
# FrenchOccupation        object
# HouseOwnerFlag           int64
# NumberCarsOwned          int64
# AddressLine1            object
# AddressLine2            object
# Phone                   object
# DateFirstPurchase       object
# CommuteDistance         object
# Region                  object
# ...

# %%
vTimeSeries.head()
# Out:
#    ModelRegion  TimeIndex  Quantity       Amount  CalendarYear  Month  \
# 0  M200 Europe     201012         1   3 399,99 ₽          2010     12
# 1  M200 Europe     201101         5  16 924,95 ₽          2011      1
# 2  M200 Europe     201102         6  20 349,94 ₽          2011      2
# 3  M200 Europe     201103         5  16 949,95 ₽          2011      3
# 4  M200 Europe     201104         5  16 949,95 ₽          2011      4
#
#         ReportingDate
# 0  25.12.2010 0:00:00
# 1  25.01.2011 0:00:00
# 2  25.02.2011 0:00:00
# 3  25.03.2011 0:00:00
# 4  25.04.2011 0:00:00

# %%
print(vTimeSeries.dtypes)
# Out:
# ModelRegion      object
# TimeIndex         int64
# Quantity          int64
# Amount           object
# CalendarYear      int64
# Month             int64
# ReportingDate    object
# dtype: object
